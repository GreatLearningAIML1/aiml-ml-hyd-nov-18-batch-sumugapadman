# %% [markdown]
# # U - Net
# ## Problem:
#
# Seismic data is collected using reflection seismology, or seismic reflection. The method requires a controlled seismic source of energy, such as compressed air or a seismic vibrator, and sensors record the reflection from rock interfaces within the subsurface. The recorded data is then processed to create a 3D view of earth’s interior. Reflection seismology is similar to X-ray, sonar and echolocation.
#
# A seismic image is produced from imaging the reflection coming from rock boundaries. The seismic image shows the boundaries between different rock types. In theory, the strength of reflection is directly proportional to the difference in the physical properties on either sides of the interface. While seismic images show rock boundaries, they don't say much about the rock themselves; some rocks are easy to identify while some are difficult.
#
# There are several areas of the world where there are vast quantities of salt in the subsurface. One of the challenges of seismic imaging is to identify the part of subsurface which is salt. Salt has characteristics that makes it both simple and hard to identify. Salt density is usually 2.14 g/cc which is lower than most surrounding rocks. The seismic velocity of salt is 4.5 km/sec, which is usually faster than its surrounding rocks. This difference creates a sharp reflection at the salt-sediment interface. Usually salt is an amorphous rock without much internal structure. This means that there is typically not much reflectivity inside the salt, unless there are sediments trapped inside it. The unusually high seismic velocity of salt can create problems with seismic imaging.
#
# ### Data
# The data is a set of images chosen at various locations chosen at random in the subsurface. The images are 101 x 101 pixels and each pixel is classified as either salt or sediment. In addition to the seismic images, the depth of the imaged location is provided for each image. The goal of the competition is to segment regions that contain salt.
#
# #### Source:
# https://www.kaggle.com/c/tgs-salt-identification-challenge
#
#
# ### Note:
# Accept the terms and download data from the above link

# %% [markdown]
# ### Aim:
#
# Implement U-Net neural model architecture in keras to solve this problem.
#
#
# In this, you are asked to segment salt deposits beneath the Earth’s surface. Given a set of seismic images that are 101 x 101 pixels each and each pixel we need to classify as either salt or sediment. Our goal is to segment regions that contain salt. A seismic image is produced from imaging the reflection coming from rock boundaries. The seismic image shows the boundaries between different rock types.

# %% [markdown]
# ### Broad Steps:
#
# 1. Download the dataset
# 2. Upload to Drive
# 3. Import from drive to colab
# 4. Load the images and create training data.
# 5. Build U-net Model
# 6. Train your model.
# 7. Check the validation accuracy and plot sample.

# %%
#Importing necessary libraries
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline

from tqdm import tqdm_notebook, tnrange
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split

import tensorflow as tf
from keras.models import Model, load_model
from keras.layers import Input, BatchNormalization, Activation, Dense, Dropout
from keras.layers.core import Lambda, RepeatVector, Reshape
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D, GlobalMaxPool2D
from keras.layers.merge import concatenate, add
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# %%
#Mount drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# ### 1.Set your project path where you have your data and related files for this lab.

# %%
project_path = "/content/drive/My Drive/Unet/"

# %% [markdown]
# ### 2. Set the necessary parameters

# %% [markdown]
# ## Setup

# %%
im_width = 128      #width of your train image
im_height = 128     #hight of your train image
#border =        
path_train = project_path + 'train/'   #Path for your train data

# %%
import os
os.chdir('/content/drive/My Drive/Unet/')

# %% [markdown]
# # 3. Make directory for train data at in your project/lab folder.
#
# Hint - use !mkdir function.

# %%
# !mkdir '/content/drive/My Drive/Unet/train'
# Out:
# mkdir: cannot create directory ‘/content/drive/My Drive/Unet/train’: File exists

# %% [markdown]
# # 4. Extract your train images to the train directory you have just created above.
# train.zip and test.zip files available at your google drive/local system.
#
# As a good practice - Upload or copy the data at your project path folder.
#
# Make sure you are providing the right project_path.

# %%
#For simplicity we have added the required code here.
from zipfile import ZipFile

with ZipFile(project_path + 'train.zip', 'r') as zf:
  zf.extractall('train/')

# %%
#The train file have both images and masks with the same names_ids.

# %% [markdown]
# ### 5. Get the list of names of images and masks and name the list imagelist and masklist.
#
# Hint - Use os.listdir() funtions.

# %%
imagelist = os.listdir('/content/drive/My Drive/Unet/train/images')
masklist = os.listdir('/content/drive/My Drive/Unet/train/masks')

# %%
#Test your list names by printing some of the names as given below.
print(imagelist[-1])
print(masklist[-1])
print(imagelist[10])
print(masklist[10])
# Out:
# 7cc53fe88b.png
# 7cc53fe88b.png
# de08c5a3b7.png
# de08c5a3b7.png

# %% [markdown]
# # 6. Read and test your images and respective masks.
#
# Hint -
#
# import  matplotlib.pyplot as plt
#
# import cv2
#
# plt.imshow(cv2.imread('path of image'))
#
# plt.imshow(cv2.imread('path of mask'))

# %%
import  matplotlib.pyplot as plt
import cv2

# %%
plt.imshow(cv2.imread('/content/drive/My Drive/Unet/train/images/{}'.format(imagelist[10])))

# %%
plt.imshow(cv2.imread('/content/drive/My Drive/Unet/train/masks/{}'.format(masklist[10])))

# %% [markdown]
# # 7. Create your training data.
#
# Hints -
#
# image_path = os.path.join(project_path +'path of your image directory' +n )
#
# mask_path = os.path.join(project_path +'path of your mask directory'+n )

# %%
# Get and resize train images and masks
def get_data(train=True):
    #ids = next(os.walk("train/images"))[2]
    X = np.zeros((len(imagelist), im_height, im_width, 1), dtype=np.float32)
    y = np.zeros((len(masklist), im_height, im_width, 1), dtype=np.float32)
    for n in imagelist:
        k = imagelist.index(n)
        image_path = os.path.join(project_path +'train/images/'+n )
        mask_path = os.path.join(project_path +'train/masks/'+n )
        
        # Load images
        img = cv2.imread(image_path, 0)
        resized_img = cv2.resize(img, (128, 128), interpolation = cv2.INTER_AREA)
        

        # Load masks
        if train:
            mask = cv2.imread(mask_path, 0)
            resized_mask = cv2.resize(mask, (128, 128), interpolation = cv2.INTER_AREA)
            resized_mask = np.reshape(resized_mask, (128,128,1))
            
           

        # Save images
        X[k, ..., 0] = resized_img.squeeze() / 255
        if train:
            y[k] = resized_mask/255
    print('Done!')
    if train:
        return X, y
    else:
        return X
    
X, y = get_data(train=True)
# Out:
# Done!

# %%
# Split train and valid
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.15, random_state=2019)

# %%
## Test your data whether it looks fine - Random check
import random 
# Check if training data looks all right
ix = random.randint(0, len(X_train))
has_mask = y_train[ix].max() > 0

fig, ax = plt.subplots(1, 2, figsize=(10, 10))

ax[0].imshow(X_train[ix, ..., 0], cmap='seismic', interpolation='bilinear')
if has_mask:
    ax[0].contour(y_train[ix].squeeze(), colors='k', levels=[0.5])
ax[0].set_title('Seismic')

ax[1].imshow(y_train[ix].squeeze(), interpolation='bilinear', cmap='gray')
ax[1].set_title('Salt');

# %% [markdown]
# ### 8. Define loss and dice_coeff function.

# %%
def dice_coefficient(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred)
    denominator = tf.reduce_sum(y_true + y_pred)

    return numerator / (denominator + tf.keras.backend.epsilon())

# %%
from keras.losses import binary_crossentropy
def loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) - tf.log(dice_coefficient(y_true, y_pred) + tf.keras.backend.epsilon())

# %% [markdown]
# ### 9. Build and compile UNet Model for your data.
#
# Hint -
# You can install and use segmentation models from this github repository.
#
# #Install segmentation models
#
# !pip install git+https://github.com/qubvel/segmentation_models

# %%
# !pip install segmentation-models
# Out:
# Requirement already satisfied: segmentation-models in /usr/local/lib/python3.6/dist-packages (1.0.0b1)
# Requirement already satisfied: efficientnet==1.0.0b3 in /usr/local/lib/python3.6/dist-packages (from segmentation-models) (1.0.0b3)
# Requirement already satisfied: image-classifiers==1.0.0b1 in /usr/local/lib/python3.6/dist-packages (from segmentation-models) (1.0.0b1)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.6/dist-packages (from segmentation-models) (1.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (2.8.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.16.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py->keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.12.0)

# %%
#Import libraries
from segmentation_models import Unet
from segmentation_models.losses import bce_jaccard_loss
from segmentation_models.metrics import iou_score

from keras.layers import Input, Conv2D, Reshape
from keras.models import Model

# %%
#model = Unet(backbone_name='resnet34', encoder_weights=None, input_shape=(None, None, 1))
#compile your model by adding the parameters like optimizer, loss and metrics.

model = Unet(backbone_name='resnet34', encoder_weights=None, input_shape=(None, None, 1))

# %%
model.compile(optimizer='Adam', loss=loss, metrics=[dice_coefficient])

# %%
#Get the summary of your model
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# data (InputLayer)               (None, None, None, 1 0
# __________________________________________________________________________________________________
# bn_data (BatchNormalization)    (None, None, None, 1 3           data[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_69 (ZeroPadding2 (None, None, None, 1 0           bn_data[0][0]
# __________________________________________________________________________________________________
# conv0 (Conv2D)                  (None, None, None, 6 3136        zero_padding2d_69[0][0]
# __________________________________________________________________________________________________
# bn0 (BatchNormalization)        (None, None, None, 6 256         conv0[0][0]
# __________________________________________________________________________________________________
# relu0 (Activation)              (None, None, None, 6 0           bn0[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_70 (ZeroPadding2 (None, None, None, 6 0           relu0[0][0]
# __________________________________________________________________________________________________
# pooling0 (MaxPooling2D)         (None, None, None, 6 0           zero_padding2d_70[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn1 (BatchNormaliz (None, None, None, 6 256         pooling0[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu1 (Activation) (None, None, None, 6 0           stage1_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_71 (ZeroPadding2 (None, None, None, 6 0           stage1_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv1 (Conv2D)     (None, None, None, 6 36864       zero_padding2d_71[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn2 (BatchNormaliz (None, None, None, 6 256         stage1_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu2 (Activation) (None, None, None, 6 0           stage1_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_72 (ZeroPadding2 (None, None, None, 6 0           stage1_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv2 (Conv2D)     (None, None, None, 6 36864       zero_padding2d_72[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_sc (Conv2D)        (None, None, None, 6 4096        stage1_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, None, None, 6 0           stage1_unit1_conv2[0][0]
#                                                                  stage1_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn1 (BatchNormaliz (None, None, None, 6 256         add_33[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu1 (Activation) (None, None, None, 6 0           stage1_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_73 (ZeroPadding2 (None, None, None, 6 0           stage1_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv1 (Conv2D)     (None, None, None, 6 36864       zero_padding2d_73[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn2 (BatchNormaliz (None, None, None, 6 256         stage1_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu2 (Activation) (None, None, None, 6 0           stage1_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_74 (ZeroPadding2 (None, None, None, 6 0           stage1_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv2 (Conv2D)     (None, None, None, 6 36864       zero_padding2d_74[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, None, None, 6 0           stage1_unit2_conv2[0][0]
#                                                                  add_33[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_bn1 (BatchNormaliz (None, None, None, 6 256         add_34[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_relu1 (Activation) (None, None, None, 6 0           stage1_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_75 (ZeroPadding2 (None, None, None, 6 0           stage1_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_conv1 (Conv2D)     (None, None, None, 6 36864       zero_padding2d_75[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_bn2 (BatchNormaliz (None, None, None, 6 256         stage1_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_relu2 (Activation) (None, None, None, 6 0           stage1_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_76 (ZeroPadding2 (None, None, None, 6 0           stage1_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_conv2 (Conv2D)     (None, None, None, 6 36864       zero_padding2d_76[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, None, None, 6 0           stage1_unit3_conv2[0][0]
#                                                                  add_34[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_bn1 (BatchNormaliz (None, None, None, 6 256         add_35[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_relu1 (Activation) (None, None, None, 6 0           stage2_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_77 (ZeroPadding2 (None, None, None, 6 0           stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_conv1 (Conv2D)     (None, None, None, 1 73728       zero_padding2d_77[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_bn2 (BatchNormaliz (None, None, None, 1 512         stage2_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_relu2 (Activation) (None, None, None, 1 0           stage2_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_78 (ZeroPadding2 (None, None, None, 1 0           stage2_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_conv2 (Conv2D)     (None, None, None, 1 147456      zero_padding2d_78[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_sc (Conv2D)        (None, None, None, 1 8192        stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, None, None, 1 0           stage2_unit1_conv2[0][0]
#                                                                  stage2_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_bn1 (BatchNormaliz (None, None, None, 1 512         add_36[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_relu1 (Activation) (None, None, None, 1 0           stage2_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_79 (ZeroPadding2 (None, None, None, 1 0           stage2_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_conv1 (Conv2D)     (None, None, None, 1 147456      zero_padding2d_79[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_bn2 (BatchNormaliz (None, None, None, 1 512         stage2_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_relu2 (Activation) (None, None, None, 1 0           stage2_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_80 (ZeroPadding2 (None, None, None, 1 0           stage2_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_conv2 (Conv2D)     (None, None, None, 1 147456      zero_padding2d_80[0][0]
# __________________________________________________________________________________________________
# add_37 (Add)                    (None, None, None, 1 0           stage2_unit2_conv2[0][0]
#                                                                  add_36[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_bn1 (BatchNormaliz (None, None, None, 1 512         add_37[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_relu1 (Activation) (None, None, None, 1 0           stage2_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_81 (ZeroPadding2 (None, None, None, 1 0           stage2_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_conv1 (Conv2D)     (None, None, None, 1 147456      zero_padding2d_81[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_bn2 (BatchNormaliz (None, None, None, 1 512         stage2_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_relu2 (Activation) (None, None, None, 1 0           stage2_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_82 (ZeroPadding2 (None, None, None, 1 0           stage2_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_conv2 (Conv2D)     (None, None, None, 1 147456      zero_padding2d_82[0][0]
# __________________________________________________________________________________________________
# add_38 (Add)                    (None, None, None, 1 0           stage2_unit3_conv2[0][0]
#                                                                  add_37[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_bn1 (BatchNormaliz (None, None, None, 1 512         add_38[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_relu1 (Activation) (None, None, None, 1 0           stage2_unit4_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_83 (ZeroPadding2 (None, None, None, 1 0           stage2_unit4_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_conv1 (Conv2D)     (None, None, None, 1 147456      zero_padding2d_83[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_bn2 (BatchNormaliz (None, None, None, 1 512         stage2_unit4_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_relu2 (Activation) (None, None, None, 1 0           stage2_unit4_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_84 (ZeroPadding2 (None, None, None, 1 0           stage2_unit4_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_conv2 (Conv2D)     (None, None, None, 1 147456      zero_padding2d_84[0][0]
# __________________________________________________________________________________________________
# add_39 (Add)                    (None, None, None, 1 0           stage2_unit4_conv2[0][0]
#                                                                  add_38[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_bn1 (BatchNormaliz (None, None, None, 1 512         add_39[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_relu1 (Activation) (None, None, None, 1 0           stage3_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_85 (ZeroPadding2 (None, None, None, 1 0           stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_conv1 (Conv2D)     (None, None, None, 2 294912      zero_padding2d_85[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_bn2 (BatchNormaliz (None, None, None, 2 1024        stage3_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_relu2 (Activation) (None, None, None, 2 0           stage3_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_86 (ZeroPadding2 (None, None, None, 2 0           stage3_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_conv2 (Conv2D)     (None, None, None, 2 589824      zero_padding2d_86[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_sc (Conv2D)        (None, None, None, 2 32768       stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_40 (Add)                    (None, None, None, 2 0           stage3_unit1_conv2[0][0]
#                                                                  stage3_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_bn1 (BatchNormaliz (None, None, None, 2 1024        add_40[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_relu1 (Activation) (None, None, None, 2 0           stage3_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_87 (ZeroPadding2 (None, None, None, 2 0           stage3_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_conv1 (Conv2D)     (None, None, None, 2 589824      zero_padding2d_87[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_bn2 (BatchNormaliz (None, None, None, 2 1024        stage3_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_relu2 (Activation) (None, None, None, 2 0           stage3_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_88 (ZeroPadding2 (None, None, None, 2 0           stage3_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_conv2 (Conv2D)     (None, None, None, 2 589824      zero_padding2d_88[0][0]
# __________________________________________________________________________________________________
# add_41 (Add)                    (None, None, None, 2 0           stage3_unit2_conv2[0][0]
#                                                                  add_40[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_bn1 (BatchNormaliz (None, None, None, 2 1024        add_41[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_relu1 (Activation) (None, None, None, 2 0           stage3_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_89 (ZeroPadding2 (None, None, None, 2 0           stage3_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_conv1 (Conv2D)     (None, None, None, 2 589824      zero_padding2d_89[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_bn2 (BatchNormaliz (None, None, None, 2 1024        stage3_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_relu2 (Activation) (None, None, None, 2 0           stage3_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_90 (ZeroPadding2 (None, None, None, 2 0           stage3_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_conv2 (Conv2D)     (None, None, None, 2 589824      zero_padding2d_90[0][0]
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, None, None, 2 0           stage3_unit3_conv2[0][0]
#                                                                  add_41[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_bn1 (BatchNormaliz (None, None, None, 2 1024        add_42[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_relu1 (Activation) (None, None, None, 2 0           stage3_unit4_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_91 (ZeroPadding2 (None, None, None, 2 0           stage3_unit4_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_conv1 (Conv2D)     (None, None, None, 2 589824      zero_padding2d_91[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_bn2 (BatchNormaliz (None, None, None, 2 1024        stage3_unit4_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_relu2 (Activation) (None, None, None, 2 0           stage3_unit4_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_92 (ZeroPadding2 (None, None, None, 2 0           stage3_unit4_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_conv2 (Conv2D)     (None, None, None, 2 589824      zero_padding2d_92[0][0]
# __________________________________________________________________________________________________
# add_43 (Add)                    (None, None, None, 2 0           stage3_unit4_conv2[0][0]
#                                                                  add_42[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_bn1 (BatchNormaliz (None, None, None, 2 1024        add_43[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_relu1 (Activation) (None, None, None, 2 0           stage3_unit5_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_93 (ZeroPadding2 (None, None, None, 2 0           stage3_unit5_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_conv1 (Conv2D)     (None, None, None, 2 589824      zero_padding2d_93[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_bn2 (BatchNormaliz (None, None, None, 2 1024        stage3_unit5_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_relu2 (Activation) (None, None, None, 2 0           stage3_unit5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_94 (ZeroPadding2 (None, None, None, 2 0           stage3_unit5_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_conv2 (Conv2D)     (None, None, None, 2 589824      zero_padding2d_94[0][0]
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, None, None, 2 0           stage3_unit5_conv2[0][0]
#                                                                  add_43[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_bn1 (BatchNormaliz (None, None, None, 2 1024        add_44[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_relu1 (Activation) (None, None, None, 2 0           stage3_unit6_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_95 (ZeroPadding2 (None, None, None, 2 0           stage3_unit6_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_conv1 (Conv2D)     (None, None, None, 2 589824      zero_padding2d_95[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_bn2 (BatchNormaliz (None, None, None, 2 1024        stage3_unit6_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_relu2 (Activation) (None, None, None, 2 0           stage3_unit6_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_96 (ZeroPadding2 (None, None, None, 2 0           stage3_unit6_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_conv2 (Conv2D)     (None, None, None, 2 589824      zero_padding2d_96[0][0]
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, None, None, 2 0           stage3_unit6_conv2[0][0]
#                                                                  add_44[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_bn1 (BatchNormaliz (None, None, None, 2 1024        add_45[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_relu1 (Activation) (None, None, None, 2 0           stage4_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_97 (ZeroPadding2 (None, None, None, 2 0           stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_conv1 (Conv2D)     (None, None, None, 5 1179648     zero_padding2d_97[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_bn2 (BatchNormaliz (None, None, None, 5 2048        stage4_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_relu2 (Activation) (None, None, None, 5 0           stage4_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_98 (ZeroPadding2 (None, None, None, 5 0           stage4_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_conv2 (Conv2D)     (None, None, None, 5 2359296     zero_padding2d_98[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_sc (Conv2D)        (None, None, None, 5 131072      stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_46 (Add)                    (None, None, None, 5 0           stage4_unit1_conv2[0][0]
#                                                                  stage4_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_bn1 (BatchNormaliz (None, None, None, 5 2048        add_46[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_relu1 (Activation) (None, None, None, 5 0           stage4_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_99 (ZeroPadding2 (None, None, None, 5 0           stage4_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_conv1 (Conv2D)     (None, None, None, 5 2359296     zero_padding2d_99[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_bn2 (BatchNormaliz (None, None, None, 5 2048        stage4_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_relu2 (Activation) (None, None, None, 5 0           stage4_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_100 (ZeroPadding (None, None, None, 5 0           stage4_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_conv2 (Conv2D)     (None, None, None, 5 2359296     zero_padding2d_100[0][0]
# __________________________________________________________________________________________________
# add_47 (Add)                    (None, None, None, 5 0           stage4_unit2_conv2[0][0]
#                                                                  add_46[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_bn1 (BatchNormaliz (None, None, None, 5 2048        add_47[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_relu1 (Activation) (None, None, None, 5 0           stage4_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_101 (ZeroPadding (None, None, None, 5 0           stage4_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_conv1 (Conv2D)     (None, None, None, 5 2359296     zero_padding2d_101[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_bn2 (BatchNormaliz (None, None, None, 5 2048        stage4_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_relu2 (Activation) (None, None, None, 5 0           stage4_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_102 (ZeroPadding (None, None, None, 5 0           stage4_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_conv2 (Conv2D)     (None, None, None, 5 2359296     zero_padding2d_102[0][0]
# __________________________________________________________________________________________________
# add_48 (Add)                    (None, None, None, 5 0           stage4_unit3_conv2[0][0]
#                                                                  add_47[0][0]
# __________________________________________________________________________________________________
# bn1 (BatchNormalization)        (None, None, None, 5 2048        add_48[0][0]
# __________________________________________________________________________________________________
# relu1 (Activation)              (None, None, None, 5 0           bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_upsampling (UpSa (None, None, None, 5 0           relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_concat (Concaten (None, None, None, 7 0           decoder_stage0_upsampling[0][0]
#                                                                  stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0a_conv (Conv2D)   (None, None, None, 2 1769472     decoder_stage0_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage0a_bn (BatchNormal (None, None, None, 2 1024        decoder_stage0a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage0a_relu (Activatio (None, None, None, 2 0           decoder_stage0a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage0b_conv (Conv2D)   (None, None, None, 2 589824      decoder_stage0a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage0b_bn (BatchNormal (None, None, None, 2 1024        decoder_stage0b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage0b_relu (Activatio (None, None, None, 2 0           decoder_stage0b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_upsampling (UpSa (None, None, None, 2 0           decoder_stage0b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_concat (Concaten (None, None, None, 3 0           decoder_stage1_upsampling[0][0]
#                                                                  stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage1a_conv (Conv2D)   (None, None, None, 1 442368      decoder_stage1_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage1a_bn (BatchNormal (None, None, None, 1 512         decoder_stage1a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage1a_relu (Activatio (None, None, None, 1 0           decoder_stage1a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage1b_conv (Conv2D)   (None, None, None, 1 147456      decoder_stage1a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage1b_bn (BatchNormal (None, None, None, 1 512         decoder_stage1b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage1b_relu (Activatio (None, None, None, 1 0           decoder_stage1b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_upsampling (UpSa (None, None, None, 1 0           decoder_stage1b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_concat (Concaten (None, None, None, 1 0           decoder_stage2_upsampling[0][0]
#                                                                  stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage2a_conv (Conv2D)   (None, None, None, 6 110592      decoder_stage2_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage2a_bn (BatchNormal (None, None, None, 6 256         decoder_stage2a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage2a_relu (Activatio (None, None, None, 6 0           decoder_stage2a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage2b_conv (Conv2D)   (None, None, None, 6 36864       decoder_stage2a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage2b_bn (BatchNormal (None, None, None, 6 256         decoder_stage2b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage2b_relu (Activatio (None, None, None, 6 0           decoder_stage2b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_upsampling (UpSa (None, None, None, 6 0           decoder_stage2b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_concat (Concaten (None, None, None, 1 0           decoder_stage3_upsampling[0][0]
#                                                                  relu0[0][0]
# __________________________________________________________________________________________________
# decoder_stage3a_conv (Conv2D)   (None, None, None, 3 36864       decoder_stage3_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage3a_bn (BatchNormal (None, None, None, 3 128         decoder_stage3a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage3a_relu (Activatio (None, None, None, 3 0           decoder_stage3a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage3b_conv (Conv2D)   (None, None, None, 3 9216        decoder_stage3a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage3b_bn (BatchNormal (None, None, None, 3 128         decoder_stage3b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage3b_relu (Activatio (None, None, None, 3 0           decoder_stage3b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_upsampling (UpSa (None, None, None, 3 0           decoder_stage3b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage4a_conv (Conv2D)   (None, None, None, 1 4608        decoder_stage4_upsampling[0][0]
# __________________________________________________________________________________________________
# decoder_stage4a_bn (BatchNormal (None, None, None, 1 64          decoder_stage4a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage4a_relu (Activatio (None, None, None, 1 0           decoder_stage4a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage4b_conv (Conv2D)   (None, None, None, 1 2304        decoder_stage4a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage4b_bn (BatchNormal (None, None, None, 1 64          decoder_stage4b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage4b_relu (Activatio (None, None, None, 1 0           decoder_stage4b_bn[0][0]
# __________________________________________________________________________________________________
# final_conv (Conv2D)             (None, None, None, 1 145         decoder_stage4b_relu[0][0]
# __________________________________________________________________________________________________
# sigmoid (Activation)            (None, None, None, 1 0           final_conv[0][0]
# ==================================================================================================
# Total params: 24,449,876
# Trainable params: 24,432,530
# Non-trainable params: 17,346
# __________________________________________________________________________________________________

# %% [markdown]
# ### 10. Fit your model using model.fit function.
# Hint - As it might take long time to run. Run it for only 1 or 2 epochs.

# %%
model.fit(
    x=X_train,
    y=y_train,
    batch_size=16,    
    epochs=2,
    validation_data=(X_valid, y_valid)
)
# Out:
# Train on 3400 samples, validate on 600 samples
# Epoch 1/2
# 3400/3400 [==============================] - 1460s 429ms/step - loss: 1.0739 - dice_coefficient: 0.5645 - val_loss: 1.2074 - val_dice_coefficient: 0.6094
# Epoch 2/2
# 3400/3400 [==============================] - 1454s 428ms/step - loss: 0.7957 - dice_coefficient: 0.6665 - val_loss: 2.0258 - val_dice_coefficient: 0.5822

# %% [markdown]
# ### 11.Predict on val set using model.predict funtion and store in preds_val variable.

# %%
preds_val = model.predict(X_valid, verbose=1)
# Out:
# 600/600 [==============================] - 63s 104ms/step

# %%
#Get the threshold predictions to look at refined results.
preds_val_t = (preds_val > 0.5).astype(np.uint8)

# %%
#Plot a sample
def plot_sample(X, y, preds, binary_preds, ix=None):
    if ix is None:
        ix = random.randint(0, len(X))

    has_mask = y[ix].max() > 0

    fig, ax = plt.subplots(1, 4, figsize=(20, 10))
    ax[0].imshow(X[ix, ..., 0], cmap='seismic')
    if has_mask:
        ax[0].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[0].set_title('Seismic')

    ax[1].imshow(y[ix].squeeze())
    ax[1].set_title('Salt')

    ax[2].imshow(preds[ix].squeeze(), vmin=0, vmax=1)
    if has_mask:
        ax[2].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[2].set_title('Salt Predicted')
    
    ax[3].imshow(binary_preds[ix].squeeze(), vmin=0, vmax=1)
    if has_mask:
        ax[3].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[3].set_title('Salt Predicted binary');

# %%
# Check if valid data looks all right
plot_sample(X_valid, y_valid, preds_val, preds_val_t, ix=15)

# %% [markdown]
# If you are getting good results- Congratulations.
# If you are not, try to explore what might be the reason.

# %% [markdown]
# # Text generation using a RNN

# %% [markdown]
# Given a sequence of words from this data, train a model to predict the next word in the sequence. Longer sequences of text can be generated by calling the model repeatedly.

# %% [markdown]
# **Mount your Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import os
os.chdir('/content/drive/My Drive/NLP/data')

# %% [markdown]
# ### Import Keras and other libraries

# %%
import glob

from sklearn.utils import shuffle
import numpy as np

from keras.preprocessing.text import Tokenizer
from keras.models import Sequential, load_model
from keras.layers import LSTM, Dense, Dropout, Embedding, Masking, Bidirectional
from keras.optimizers import Adam
from keras import backend

# %% [markdown]
# ## Download data
# Reference: Data is collected from http://www.gutenberg.org
#
# For the lab purpose, you can load the dataset provided by Great Learning

# %% [markdown]
# ### Load the Oscar Wilde dataset
#
# Store all the ".txt" file names in a list

# %%
filelist = glob.glob("/content/drive/My Drive/NLP/data/*.txt")

# %% [markdown]
# ### Read the data
#
# Read contents of every file from the list and append the text in a new list

# %%
text_data = []
for file in filelist:
    with open(file, "r") as file:
      text_data.append(file.read())

# %% [markdown]
# ## Process the text
# Initialize and fit the tokenizer

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(text_data)

# %% [markdown]
# ### Vectorize the text
#
# Before training, we need to map strings to a numerical representation. Create two lookup tables: one mapping words to numbers, and another for numbers to words.

# %%
word_idx = tokenizer.word_index #Last is the key
idx_word = tokenizer.index_word

# %% [markdown]
# Get the word count for every word and also get the total number of words.

# %%
word_counts = tokenizer.word_counts
num_words = len(word_counts)

# %%
print(num_words)
# Out:
# 14787

# %% [markdown]
# Convert text to sequence of numbers

# %%
sequences = tokenizer.texts_to_sequences(text_data)

# %% [markdown]
# ### Generate Features and Labels

# %%
features = []
labels = []

training_length = 50
# Iterate through the sequences of tokens
for seq in sequences:
    # Create multiple training examples from each sequence
    for i in range(training_length, training_length+300):
        # Extract the features and label
        extract = seq[i - training_length: i - training_length + 20]

        # Set the features and label
        features.append(extract[:-1])
        labels.append(extract[-1])

# %% [markdown]
# ### The prediction task

# %% [markdown]
# Given a word, or a sequence of words, what is the most probable next word? This is the task we're training the model to perform. The input to the model will be a sequence of words, and we train the model to predict the output—the following word at each time step.
#
# Since RNNs maintain an internal state that depends on the previously seen elements, given all the words computed until this moment, what is the next word?

# %% [markdown]
# ### Generate training and testing data

# %%
from sklearn.utils import shuffle
import numpy as np

features, labels = shuffle(features, labels, random_state=1)

# Decide on number of samples for training
train_end = int(0.75 * len(labels))

train_features = np.array(features[:train_end])
valid_features = np.array(features[train_end:])

train_labels = labels[:train_end]
valid_labels = labels[train_end:]

# Convert to arrays
X_train, X_valid = np.array(train_features), np.array(valid_features)

# Using int8 for memory savings
y_train = np.zeros((len(train_labels), num_words), dtype=np.int8)
y_valid = np.zeros((len(valid_labels), num_words), dtype=np.int8)

# One hot encoding of labels
for example_index, word_index in enumerate(train_labels):
    y_train[example_index, word_index] = 1

for example_index, word_index in enumerate(valid_labels):
    y_valid[example_index, word_index] = 1

# %% [markdown]
# This is just to check the features and labels

# %%
for i, sequence in enumerate(X_train[:1]):
    text = []
    for idx in sequence:
        text.append(idx_word[idx])
        
    print('Features: ' + ' '.join(text)+'\n')
    print('Label: ' + idx_word[np.argmax(y_train[i])] + '\n')
# Out:
# Features: influence of the impressionists on climate an exposure to naturalism thomas griffiths wainewright wainewright at hobart town cardinal newman
#
# Label: and

# %% [markdown]
# ## Build The Model

# %% [markdown]
# Use `keras.Sequential` to define the model. For this simple example three layers are used to define our model:
#
# * `keras.layers.Embedding`: The input layer. A trainable lookup table that will map the numbers of each character to a vector with `embedding_dim` dimensions;
# * `keras.layers.LSTM`: A type of RNN with size `units=rnn_units` (You can also use a GRU layer here.)
# * `keras.layers.Dense`: The output layer, with `num_words` outputs.

# %%
model = Sequential()

# Embedding layer
model.add(
    Embedding(
        input_dim=num_words,
        output_dim=100,
        weights=None,
        trainable=True))

# Recurrent layer
model.add(
    LSTM(
        64, return_sequences=False, dropout=0.1,
        recurrent_dropout=0.1))

# Fully connected layer
model.add(Dense(64, activation='relu'))

# Dropout for regularization
model.add(Dropout(0.5))

# Output layer
model.add(Dense(num_words, activation='softmax'))

# Compile the model
model.compile(
    optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# W0811 15:19:32.929295 140607297980288 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, None, 100)         1478700
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                42240
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 14787)             961155
# =================================================================
# Total params: 2,486,255
# Trainable params: 2,486,255
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# For each word the model looks up the embedding, runs the LSTM one timestep with the embedding as input, and applies the dense layer to generate logits predicting the log-liklihood of the next word.

# %% [markdown]
# ## Train the model

# %%
h = model.fit(X_train, y_train, epochs = 1, batch_size = 500, verbose = 1)
# Out:
# Epoch 1/1
# 2250/2250 [==============================] - 7s 3ms/step - loss: 9.5994 - acc: 0.0089

# %% [markdown]
# ### Save Model

# %%
model.save('/content/drive/My Drive/NLP/data/model_1000epochs.h5')

# %% [markdown]
# ## If you have already trained the model and saved it, you can load a pretrained model

# %%
model = load_model('/content/drive/My Drive/NLP/data/model_1000epochs.h5')

# %% [markdown]
# ### Note: After loading the model run  model.fit()  to continue training form there, if required.

# %%
model.fit(X_train, y_train, batch_size=50, epochs=500)
# Out:
# Epoch 1/500
# 2250/2250 [==============================] - 5s 2ms/step - loss: 8.5924 - acc: 0.0569
# Epoch 2/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 6.6905 - acc: 0.0702
# Epoch 3/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 6.4246 - acc: 0.0724
# Epoch 4/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 6.2666 - acc: 0.0729
# Epoch 5/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 6.1439 - acc: 0.0729
# Epoch 6/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 6.0545 - acc: 0.0729
# Epoch 7/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 5.9672 - acc: 0.0702
# Epoch 8/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 5.9056 - acc: 0.0729
# Epoch 9/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 5.8534 - acc: 0.0702
# Epoch 10/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 5.7990 - acc: 0.0720
# Epoch 11/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 5.7787 - acc: 0.0720
# Epoch 12/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 5.7460 - acc: 0.0716
# Epoch 13/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 5.7158 - acc: 0.0738
# Epoch 14/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 5.6895 - acc: 0.0733
# Epoch 15/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 5.6637 - acc: 0.0702
# Epoch 16/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 5.6485 - acc: 0.0684
# Epoch 17/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 5.5938 - acc: 0.0720
# Epoch 18/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 5.5559 - acc: 0.0747
# Epoch 19/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 5.5273 - acc: 0.0698
# Epoch 20/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 5.4862 - acc: 0.0787
# Epoch 21/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 5.4299 - acc: 0.0707
# Epoch 22/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 5.3843 - acc: 0.0733
# Epoch 23/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 5.3099 - acc: 0.0809
# Epoch 24/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 5.2802 - acc: 0.0836
# Epoch 25/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 5.2017 - acc: 0.0844
# Epoch 26/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 5.1568 - acc: 0.0858
# Epoch 27/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 5.0923 - acc: 0.0920
# Epoch 28/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 5.0489 - acc: 0.0836
# Epoch 29/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 5.0130 - acc: 0.0898
# Epoch 30/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 4.9470 - acc: 0.0911
# Epoch 31/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 4.8881 - acc: 0.0987
# Epoch 32/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 4.8445 - acc: 0.0942
# Epoch 33/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 4.7840 - acc: 0.1071
# Epoch 34/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 4.6983 - acc: 0.1102
# Epoch 35/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 4.6267 - acc: 0.1227
# Epoch 36/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 4.5718 - acc: 0.1231
# Epoch 37/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 4.4973 - acc: 0.1324
# Epoch 38/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 4.4252 - acc: 0.1476
# Epoch 39/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 4.3438 - acc: 0.1493
# Epoch 40/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 4.2821 - acc: 0.1604
# Epoch 41/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 4.1919 - acc: 0.1613
# Epoch 42/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 4.1164 - acc: 0.1689
# Epoch 43/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 4.0621 - acc: 0.1764
# Epoch 44/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 4.0046 - acc: 0.1711
# Epoch 45/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 3.9008 - acc: 0.1880
# Epoch 46/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 3.8570 - acc: 0.1982
# Epoch 47/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 3.7573 - acc: 0.2080
# Epoch 48/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 3.7118 - acc: 0.2071
# Epoch 49/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 3.6514 - acc: 0.2178
# Epoch 50/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 3.5813 - acc: 0.2262
# Epoch 51/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 3.5451 - acc: 0.2307
# Epoch 52/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 3.4800 - acc: 0.2400
# Epoch 53/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 3.4198 - acc: 0.2444
# Epoch 54/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 3.3492 - acc: 0.2533
# Epoch 55/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 3.2944 - acc: 0.2564
# Epoch 56/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 3.2437 - acc: 0.2631
# Epoch 57/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 3.1748 - acc: 0.2787
# Epoch 58/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 3.0865 - acc: 0.2898
# Epoch 59/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 3.0399 - acc: 0.2898
# Epoch 60/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 3.0450 - acc: 0.2853
# Epoch 61/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 2.9500 - acc: 0.3098
# Epoch 62/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 2.9100 - acc: 0.3116
# Epoch 63/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 2.8337 - acc: 0.3320
# Epoch 64/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 2.7961 - acc: 0.3351
# Epoch 65/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 2.7109 - acc: 0.3409
# Epoch 66/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 2.6537 - acc: 0.3564
# Epoch 67/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 2.6241 - acc: 0.3529
# Epoch 68/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 2.5925 - acc: 0.3698
# Epoch 69/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 2.5256 - acc: 0.3720
# Epoch 70/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 2.4986 - acc: 0.3742
# Epoch 71/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 2.4247 - acc: 0.3942
# Epoch 72/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 2.3999 - acc: 0.4018
# Epoch 73/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 2.3426 - acc: 0.4080
# Epoch 74/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 2.2924 - acc: 0.4089
# Epoch 75/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 2.2558 - acc: 0.4138
# Epoch 76/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 2.2095 - acc: 0.4333
# Epoch 77/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 2.1924 - acc: 0.4324
# Epoch 78/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 2.1660 - acc: 0.4427
# Epoch 79/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 2.1173 - acc: 0.4538
# Epoch 80/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 2.0869 - acc: 0.4413
# Epoch 81/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 2.0799 - acc: 0.4511
# Epoch 82/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 2.0169 - acc: 0.4698
# Epoch 83/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.9762 - acc: 0.4929
# Epoch 84/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.9415 - acc: 0.4849
# Epoch 85/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.8923 - acc: 0.5164
# Epoch 86/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.9215 - acc: 0.4911
# Epoch 87/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.8733 - acc: 0.4920
# Epoch 88/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.8241 - acc: 0.5044
# Epoch 89/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.8189 - acc: 0.5004
# Epoch 90/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.7517 - acc: 0.5262
# Epoch 91/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.7728 - acc: 0.5147
# Epoch 92/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.7379 - acc: 0.5249
# Epoch 93/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.6818 - acc: 0.5409
# Epoch 94/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.6541 - acc: 0.5476
# Epoch 95/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.6055 - acc: 0.5413
# Epoch 96/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.6303 - acc: 0.5538
# Epoch 97/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.5819 - acc: 0.5667
# Epoch 98/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.6088 - acc: 0.5569
# Epoch 99/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.5497 - acc: 0.5716
# Epoch 100/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.5543 - acc: 0.5787
# Epoch 101/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.4975 - acc: 0.5782
# Epoch 102/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.4868 - acc: 0.5862
# Epoch 103/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.4655 - acc: 0.5871
# Epoch 104/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.4415 - acc: 0.5822
# Epoch 105/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.4379 - acc: 0.5991
# Epoch 106/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.4267 - acc: 0.5916
# Epoch 107/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.3812 - acc: 0.6089
# Epoch 108/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.3687 - acc: 0.6040
# Epoch 109/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.3366 - acc: 0.6262
# Epoch 110/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.3006 - acc: 0.6249
# Epoch 111/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.3010 - acc: 0.6351
# Epoch 112/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.2956 - acc: 0.6307
# Epoch 113/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.2378 - acc: 0.6418
# Epoch 114/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.2686 - acc: 0.6369
# Epoch 115/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.2298 - acc: 0.6507
# Epoch 116/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.1885 - acc: 0.6667
# Epoch 117/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.2241 - acc: 0.6413
# Epoch 118/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.1988 - acc: 0.6551
# Epoch 119/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.1925 - acc: 0.6591
# Epoch 120/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.1628 - acc: 0.6631
# Epoch 121/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.1594 - acc: 0.6689
# Epoch 122/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.1520 - acc: 0.6609
# Epoch 123/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.1554 - acc: 0.6658
# Epoch 124/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.1836 - acc: 0.6542
# Epoch 125/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.1186 - acc: 0.6742
# Epoch 126/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.1181 - acc: 0.6738
# Epoch 127/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.1055 - acc: 0.6800
# Epoch 128/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.0577 - acc: 0.6809
# Epoch 129/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.0925 - acc: 0.6693
# Epoch 130/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.0568 - acc: 0.6889
# Epoch 131/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.0530 - acc: 0.6764
# Epoch 132/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.0489 - acc: 0.6853
# Epoch 133/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.9958 - acc: 0.7098
# Epoch 134/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.0300 - acc: 0.6862
# Epoch 135/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.9983 - acc: 0.7138
# Epoch 136/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.0010 - acc: 0.6889
# Epoch 137/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 1.0048 - acc: 0.6973
# Epoch 138/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.9675 - acc: 0.7182
# Epoch 139/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.9898 - acc: 0.7151
# Epoch 140/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.9633 - acc: 0.7209
# Epoch 141/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.9590 - acc: 0.7138
# Epoch 142/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.9252 - acc: 0.7271
# Epoch 143/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.9504 - acc: 0.7129
# Epoch 144/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.9274 - acc: 0.7209
# Epoch 145/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.9032 - acc: 0.7311
# Epoch 146/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.9035 - acc: 0.7329
# Epoch 147/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.8887 - acc: 0.7400
# Epoch 148/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.8918 - acc: 0.7320
# Epoch 149/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.8830 - acc: 0.7316
# Epoch 150/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.8230 - acc: 0.7587
# Epoch 151/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.9039 - acc: 0.7244
# Epoch 152/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.8391 - acc: 0.7400
# Epoch 153/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.8560 - acc: 0.7471
# Epoch 154/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.8580 - acc: 0.7409
# Epoch 155/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.8158 - acc: 0.7533
# Epoch 156/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.8238 - acc: 0.7436
# Epoch 157/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.8874 - acc: 0.7369
# Epoch 158/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.8594 - acc: 0.7387
# Epoch 159/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.8279 - acc: 0.7547
# Epoch 160/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.7935 - acc: 0.7631
# Epoch 161/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.8369 - acc: 0.7440
# Epoch 162/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.8079 - acc: 0.7489
# Epoch 163/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.7869 - acc: 0.7564
# Epoch 164/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.7525 - acc: 0.7747
# Epoch 165/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.7707 - acc: 0.7564
# Epoch 166/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.7796 - acc: 0.7582
# Epoch 167/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.7304 - acc: 0.7769
# Epoch 168/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.7667 - acc: 0.7649
# Epoch 169/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.7448 - acc: 0.7773
# Epoch 170/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.8086 - acc: 0.7529
# Epoch 171/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.7599 - acc: 0.7671
# Epoch 172/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.7219 - acc: 0.7769
# Epoch 173/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.7373 - acc: 0.7698
# Epoch 174/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.7196 - acc: 0.7809
# Epoch 175/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.7180 - acc: 0.7760
# Epoch 176/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.6946 - acc: 0.7876
# Epoch 177/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.7222 - acc: 0.7809
# Epoch 178/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.7130 - acc: 0.7831
# Epoch 179/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.6939 - acc: 0.7831
# Epoch 180/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.7119 - acc: 0.7813
# Epoch 181/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.6823 - acc: 0.7902
# Epoch 182/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.6951 - acc: 0.7844
# Epoch 183/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.6913 - acc: 0.7813
# Epoch 184/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.6648 - acc: 0.7764
# Epoch 185/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.6490 - acc: 0.7893
# Epoch 186/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.6659 - acc: 0.7898
# Epoch 187/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.6714 - acc: 0.8031
# Epoch 188/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.6391 - acc: 0.7938
# Epoch 189/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.6311 - acc: 0.8013
# Epoch 190/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.6727 - acc: 0.7951
# Epoch 191/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.6551 - acc: 0.7924
# Epoch 192/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.6231 - acc: 0.8133
# Epoch 193/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.6394 - acc: 0.7982
# Epoch 194/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.6348 - acc: 0.7951
# Epoch 195/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.6427 - acc: 0.7969
# Epoch 196/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.6479 - acc: 0.7924
# Epoch 197/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.6235 - acc: 0.7991
# Epoch 198/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.6551 - acc: 0.7831
# Epoch 199/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.6443 - acc: 0.7942
# Epoch 200/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.6296 - acc: 0.8058
# Epoch 201/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.6146 - acc: 0.8009
# Epoch 202/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.6043 - acc: 0.8080
# Epoch 203/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.6130 - acc: 0.8111
# Epoch 204/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.6082 - acc: 0.8022
# Epoch 205/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.6032 - acc: 0.8089
# Epoch 206/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.6034 - acc: 0.8147
# Epoch 207/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.5879 - acc: 0.8111
# Epoch 208/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.6315 - acc: 0.8022
# Epoch 209/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.5836 - acc: 0.8129
# Epoch 210/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.5896 - acc: 0.8098
# Epoch 211/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.5925 - acc: 0.8053
# Epoch 212/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.5939 - acc: 0.8120
# Epoch 213/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.5868 - acc: 0.8076
# Epoch 214/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.5473 - acc: 0.8320
# Epoch 215/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.6136 - acc: 0.8022
# Epoch 216/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.5550 - acc: 0.8262
# Epoch 217/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.5387 - acc: 0.8324
# Epoch 218/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.5804 - acc: 0.8187
# Epoch 219/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.5708 - acc: 0.8236
# Epoch 220/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.5325 - acc: 0.8329
# Epoch 221/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.5604 - acc: 0.8222
# Epoch 222/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.5480 - acc: 0.8298
# Epoch 223/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.5528 - acc: 0.8222
# Epoch 224/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.5713 - acc: 0.8276
# Epoch 225/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.5758 - acc: 0.8053
# Epoch 226/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.5277 - acc: 0.8360
# Epoch 227/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.5320 - acc: 0.8409
# Epoch 228/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.5417 - acc: 0.8320
# Epoch 229/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.5446 - acc: 0.8240
# Epoch 230/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.5135 - acc: 0.8364
# Epoch 231/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.5075 - acc: 0.8364
# Epoch 232/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.5077 - acc: 0.8391
# Epoch 233/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.5185 - acc: 0.8347
# Epoch 234/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.5113 - acc: 0.8311
# Epoch 235/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.5039 - acc: 0.8373
# Epoch 236/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.5230 - acc: 0.8338
# Epoch 237/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4839 - acc: 0.8378
# Epoch 238/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4971 - acc: 0.8413
# Epoch 239/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.5216 - acc: 0.8400
# Epoch 240/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4788 - acc: 0.8422
# Epoch 241/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.5440 - acc: 0.8218
# Epoch 242/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4840 - acc: 0.8382
# Epoch 243/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4808 - acc: 0.8413
# Epoch 244/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.5049 - acc: 0.8333
# Epoch 245/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4756 - acc: 0.8382
# Epoch 246/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.5164 - acc: 0.8302
# Epoch 247/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4940 - acc: 0.8471
# Epoch 248/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4955 - acc: 0.8347
# Epoch 249/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4723 - acc: 0.8524
# Epoch 250/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4728 - acc: 0.8516
# Epoch 251/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4408 - acc: 0.8613
# Epoch 252/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4797 - acc: 0.8520
# Epoch 253/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4736 - acc: 0.8529
# Epoch 254/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4762 - acc: 0.8560
# Epoch 255/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4645 - acc: 0.8520
# Epoch 256/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4602 - acc: 0.8564
# Epoch 257/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4702 - acc: 0.8449
# Epoch 258/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4571 - acc: 0.8569
# Epoch 259/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4699 - acc: 0.8467
# Epoch 260/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4672 - acc: 0.8427
# Epoch 261/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4884 - acc: 0.8409
# Epoch 262/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4641 - acc: 0.8502
# Epoch 263/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4404 - acc: 0.8631
# Epoch 264/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4726 - acc: 0.8382
# Epoch 265/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4681 - acc: 0.8498
# Epoch 266/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4484 - acc: 0.8596
# Epoch 267/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4462 - acc: 0.8564
# Epoch 268/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4582 - acc: 0.8556
# Epoch 269/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4479 - acc: 0.8542
# Epoch 270/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4475 - acc: 0.8556
# Epoch 271/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4638 - acc: 0.8440
# Epoch 272/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4438 - acc: 0.8596
# Epoch 273/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4408 - acc: 0.8476
# Epoch 274/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4461 - acc: 0.8631
# Epoch 275/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4384 - acc: 0.8560
# Epoch 276/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4505 - acc: 0.8480
# Epoch 277/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4079 - acc: 0.8729
# Epoch 278/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4128 - acc: 0.8676
# Epoch 279/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4510 - acc: 0.8564
# Epoch 280/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4635 - acc: 0.8471
# Epoch 281/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4438 - acc: 0.8480
# Epoch 282/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4350 - acc: 0.8591
# Epoch 283/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3961 - acc: 0.8831
# Epoch 284/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4015 - acc: 0.8720
# Epoch 285/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4480 - acc: 0.8618
# Epoch 286/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4296 - acc: 0.8596
# Epoch 287/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4196 - acc: 0.8613
# Epoch 288/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4214 - acc: 0.8560
# Epoch 289/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4093 - acc: 0.8640
# Epoch 290/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3978 - acc: 0.8760
# Epoch 291/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4010 - acc: 0.8720
# Epoch 292/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3795 - acc: 0.8711
# Epoch 293/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4058 - acc: 0.8684
# Epoch 294/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4185 - acc: 0.8542
# Epoch 295/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3847 - acc: 0.8809
# Epoch 296/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4263 - acc: 0.8640
# Epoch 297/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4024 - acc: 0.8693
# Epoch 298/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3818 - acc: 0.8640
# Epoch 299/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3872 - acc: 0.8747
# Epoch 300/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3724 - acc: 0.8796
# Epoch 301/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4053 - acc: 0.8684
# Epoch 302/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3970 - acc: 0.8636
# Epoch 303/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3656 - acc: 0.8738
# Epoch 304/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3763 - acc: 0.8729
# Epoch 305/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3915 - acc: 0.8747
# Epoch 306/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3966 - acc: 0.8729
# Epoch 307/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3822 - acc: 0.8804
# Epoch 308/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.4084 - acc: 0.8658
# Epoch 309/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3878 - acc: 0.8733
# Epoch 310/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3620 - acc: 0.8827
# Epoch 311/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3819 - acc: 0.8747
# Epoch 312/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3841 - acc: 0.8742
# Epoch 313/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3759 - acc: 0.8738
# Epoch 314/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3751 - acc: 0.8729
# Epoch 315/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3753 - acc: 0.8689
# Epoch 316/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3914 - acc: 0.8760
# Epoch 317/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3729 - acc: 0.8738
# Epoch 318/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3463 - acc: 0.8831
# Epoch 319/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3863 - acc: 0.8689
# Epoch 320/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3895 - acc: 0.8720
# Epoch 321/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3997 - acc: 0.8618
# Epoch 322/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3776 - acc: 0.8804
# Epoch 323/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3623 - acc: 0.8813
# Epoch 324/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3512 - acc: 0.8884
# Epoch 325/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3777 - acc: 0.8760
# Epoch 326/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3728 - acc: 0.8778
# Epoch 327/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3549 - acc: 0.8796
# Epoch 328/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3714 - acc: 0.8747
# Epoch 329/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3366 - acc: 0.8853
# Epoch 330/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3341 - acc: 0.9009
# Epoch 331/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3501 - acc: 0.8889
# Epoch 332/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3456 - acc: 0.8853
# Epoch 333/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3916 - acc: 0.8702
# Epoch 334/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3423 - acc: 0.8871
# Epoch 335/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3733 - acc: 0.8711
# Epoch 336/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3302 - acc: 0.8831
# Epoch 337/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3544 - acc: 0.8884
# Epoch 338/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3434 - acc: 0.8804
# Epoch 339/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3657 - acc: 0.8800
# Epoch 340/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3461 - acc: 0.8924
# Epoch 341/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3282 - acc: 0.8938
# Epoch 342/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3582 - acc: 0.8809
# Epoch 343/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3527 - acc: 0.8880
# Epoch 344/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3568 - acc: 0.8853
# Epoch 345/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3588 - acc: 0.8791
# Epoch 346/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3467 - acc: 0.8844
# Epoch 347/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3256 - acc: 0.8964
# Epoch 348/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3411 - acc: 0.8853
# Epoch 349/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3518 - acc: 0.8898
# Epoch 350/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3364 - acc: 0.8898
# Epoch 351/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3182 - acc: 0.8889
# Epoch 352/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3098 - acc: 0.8902
# Epoch 353/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3469 - acc: 0.8871
# Epoch 354/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3083 - acc: 0.8929
# Epoch 355/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3457 - acc: 0.8791
# Epoch 356/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3596 - acc: 0.8813
# Epoch 357/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3376 - acc: 0.8898
# Epoch 358/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3198 - acc: 0.8920
# Epoch 359/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3484 - acc: 0.8844
# Epoch 360/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3305 - acc: 0.8929
# Epoch 361/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3426 - acc: 0.8880
# Epoch 362/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3222 - acc: 0.8898
# Epoch 363/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3438 - acc: 0.8844
# Epoch 364/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3420 - acc: 0.8782
# Epoch 365/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3222 - acc: 0.8893
# Epoch 366/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3351 - acc: 0.8849
# Epoch 367/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3151 - acc: 0.8973
# Epoch 368/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3272 - acc: 0.8911
# Epoch 369/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2941 - acc: 0.9058
# Epoch 370/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3205 - acc: 0.8964
# Epoch 371/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3009 - acc: 0.9053
# Epoch 372/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3229 - acc: 0.8924
# Epoch 373/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3170 - acc: 0.8876
# Epoch 374/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3301 - acc: 0.8947
# Epoch 375/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3179 - acc: 0.8902
# Epoch 376/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3301 - acc: 0.8938
# Epoch 377/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2919 - acc: 0.9013
# Epoch 378/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3162 - acc: 0.8898
# Epoch 379/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2901 - acc: 0.9044
# Epoch 380/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3086 - acc: 0.8956
# Epoch 381/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3332 - acc: 0.8947
# Epoch 382/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2924 - acc: 0.9027
# Epoch 383/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3504 - acc: 0.8871
# Epoch 384/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3243 - acc: 0.9071
# Epoch 385/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2885 - acc: 0.9040
# Epoch 386/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2898 - acc: 0.9022
# Epoch 387/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2871 - acc: 0.9071
# Epoch 388/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3116 - acc: 0.8982
# Epoch 389/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3070 - acc: 0.8982
# Epoch 390/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2994 - acc: 0.8987
# Epoch 391/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2928 - acc: 0.8960
# Epoch 392/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2815 - acc: 0.9089
# Epoch 393/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2874 - acc: 0.9004
# Epoch 394/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2964 - acc: 0.8987
# Epoch 395/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3096 - acc: 0.9040
# Epoch 396/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3349 - acc: 0.8902
# Epoch 397/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3205 - acc: 0.8902
# Epoch 398/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3097 - acc: 0.8978
# Epoch 399/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2893 - acc: 0.9040
# Epoch 400/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2905 - acc: 0.9027
# Epoch 401/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2991 - acc: 0.8996
# Epoch 402/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2690 - acc: 0.9089
# Epoch 403/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3019 - acc: 0.9022
# Epoch 404/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2928 - acc: 0.9013
# Epoch 405/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3270 - acc: 0.8947
# Epoch 406/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2635 - acc: 0.9093
# Epoch 407/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2827 - acc: 0.9089
# Epoch 408/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2731 - acc: 0.9120
# Epoch 409/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3046 - acc: 0.9004
# Epoch 410/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3018 - acc: 0.9058
# Epoch 411/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2885 - acc: 0.9027
# Epoch 412/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2782 - acc: 0.9160
# Epoch 413/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3099 - acc: 0.9027
# Epoch 414/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2694 - acc: 0.9151
# Epoch 415/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3058 - acc: 0.9022
# Epoch 416/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3005 - acc: 0.8929
# Epoch 417/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2607 - acc: 0.9129
# Epoch 418/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3038 - acc: 0.8960
# Epoch 419/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2752 - acc: 0.9116
# Epoch 420/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.3019 - acc: 0.8960
# Epoch 421/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2838 - acc: 0.8964
# Epoch 422/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2772 - acc: 0.9040
# Epoch 423/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2996 - acc: 0.8978
# Epoch 424/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2801 - acc: 0.9044
# Epoch 425/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2646 - acc: 0.9071
# Epoch 426/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2837 - acc: 0.9107
# Epoch 427/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2846 - acc: 0.9000
# Epoch 428/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2955 - acc: 0.9058
# Epoch 429/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2905 - acc: 0.9013
# Epoch 430/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2582 - acc: 0.9156
# Epoch 431/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2826 - acc: 0.9084
# Epoch 432/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2964 - acc: 0.8960
# Epoch 433/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2792 - acc: 0.9084
# Epoch 434/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2651 - acc: 0.9107
# Epoch 435/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2825 - acc: 0.9120
# Epoch 436/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2435 - acc: 0.9178
# Epoch 437/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2656 - acc: 0.9080
# Epoch 438/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2787 - acc: 0.9089
# Epoch 439/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2793 - acc: 0.9133
# Epoch 440/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2809 - acc: 0.9058
# Epoch 441/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2621 - acc: 0.9156
# Epoch 442/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2573 - acc: 0.9151
# Epoch 443/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2722 - acc: 0.9089
# Epoch 444/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2783 - acc: 0.9031
# Epoch 445/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2602 - acc: 0.9120
# Epoch 446/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2675 - acc: 0.9084
# Epoch 447/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2834 - acc: 0.9076
# Epoch 448/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2607 - acc: 0.9084
# Epoch 449/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2929 - acc: 0.9022
# Epoch 450/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2718 - acc: 0.9129
# Epoch 451/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2521 - acc: 0.9107
# Epoch 452/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2793 - acc: 0.9040
# Epoch 453/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2817 - acc: 0.9124
# Epoch 454/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2631 - acc: 0.9156
# Epoch 455/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2564 - acc: 0.9169
# Epoch 456/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2819 - acc: 0.9044
# Epoch 457/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2738 - acc: 0.9053
# Epoch 458/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2668 - acc: 0.9142
# Epoch 459/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2520 - acc: 0.9098
# Epoch 460/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2479 - acc: 0.9200
# Epoch 461/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2298 - acc: 0.9236
# Epoch 462/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2542 - acc: 0.9111
# Epoch 463/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2575 - acc: 0.9129
# Epoch 464/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2461 - acc: 0.9178
# Epoch 465/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2557 - acc: 0.9084
# Epoch 466/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2545 - acc: 0.9160
# Epoch 467/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2787 - acc: 0.9022
# Epoch 468/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2424 - acc: 0.9200
# Epoch 469/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2444 - acc: 0.9209
# Epoch 470/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2740 - acc: 0.9080
# Epoch 471/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2734 - acc: 0.9124
# Epoch 472/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2411 - acc: 0.9236
# Epoch 473/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2524 - acc: 0.9169
# Epoch 474/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2658 - acc: 0.9098
# Epoch 475/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2369 - acc: 0.9191
# Epoch 476/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2751 - acc: 0.9067
# Epoch 477/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2606 - acc: 0.9160
# Epoch 478/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2468 - acc: 0.9156
# Epoch 479/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2718 - acc: 0.9071
# Epoch 480/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2251 - acc: 0.9276
# Epoch 481/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2533 - acc: 0.9116
# Epoch 482/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2713 - acc: 0.9053
# Epoch 483/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2687 - acc: 0.9151
# Epoch 484/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2482 - acc: 0.9182
# Epoch 485/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2294 - acc: 0.9258
# Epoch 486/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2452 - acc: 0.9191
# Epoch 487/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2338 - acc: 0.9196
# Epoch 488/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2757 - acc: 0.9133
# Epoch 489/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2598 - acc: 0.9124
# Epoch 490/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2608 - acc: 0.9209
# Epoch 491/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2472 - acc: 0.9178
# Epoch 492/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2515 - acc: 0.9129
# Epoch 493/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2499 - acc: 0.9124
# Epoch 494/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2485 - acc: 0.9204
# Epoch 495/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2610 - acc: 0.9062
# Epoch 496/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2437 - acc: 0.9173
# Epoch 497/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2594 - acc: 0.9089
# Epoch 498/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2498 - acc: 0.9142
# Epoch 499/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2370 - acc: 0.9182
# Epoch 500/500
# 2250/2250 [==============================] - 4s 2ms/step - loss: 0.2327 - acc: 0.9222

# %% [markdown]
# ## Evaluation

# %%
print(model.evaluate(X_train, y_train, batch_size = 20))
print('\nModel Performance: Log Loss and Accuracy on validation data')
print(model.evaluate(X_valid, y_valid, batch_size = 20))
# Out:
# 2250/2250 [==============================] - 3s 1ms/step
# [0.009565313935745508, 0.9955555544959174]
#
# Model Performance: Log Loss and Accuracy on validation data
# 750/750 [==============================] - 0s 534us/step
# [10.280761171976724, 0.3000000027815501]

# %% [markdown]
# ## Generate text

# %%
seed_length=50
new_words=50
diversity=1
n_gen=1

import random

# Choose a random sequence
seq = random.choice(sequences)

# print seq

# Choose a random starting point
seed_idx = random.randint(0, len(seq) - seed_length - 10)
# Ending index for seed
end_idx = seed_idx + seed_length

# %%
gen_list = []

for n in range(n_gen):
    # Extract the seed sequence
    seed = seq[seed_idx:end_idx]
    original_sequence = [idx_word[i] for i in seed]
    generated = seed[:] + ['#']

    # Find the actual entire sequence
    actual = generated[:] + seq[end_idx:end_idx + new_words]
        
    # Keep adding new words
    for i in range(new_words):

        # Make a prediction from the seed
        preds = model.predict(np.array(seed).reshape(1, -1))[0].astype(np.float64)
        exp_preds = np.exp(preds)

  
        # Softmax
        preds = exp_preds / sum(exp_preds)

        # Choose the next word
        probas = np.random.multinomial(1, preds, 1)[0]

        next_idx = np.argmax(probas)

        # New seed adds on old word
        #             seed = seed[1:] + [next_idx]
        seed += [next_idx]
        generated.append(next_idx)
    # Showing generated and actual abstract
    n = []

    for i in generated:
        n.append(idx_word.get(i, '< --- >'))

    gen_list.append(n)

# %%
a = []

for i in actual:
    a.append(idx_word.get(i, '< --- >'))

a = a[seed_length:]

gen_list = [gen[seed_length:seed_length + len(a)] for gen in gen_list]

print('Sequence: \n'+' '.join(original_sequence))
# Out:
# Sequence:
# till i have learned your secret runs laughing into the corridor guido oh horrible had i so soon forgot my father’s death did i so soon let love into my heart and must i banish love and let in murder that beats and clamours at the outer gate ay that

# %% [markdown]
# ## Time Series Analysis using LSTM

# %% [markdown]
# ### Download Data
# Link: https://datamarket.com/data/set/2324/daily-minimum-temperatures-in-melbourne-australia-1981-1990#!ds=2324&display=line
#
# #### Description
# Daily minimum temperatures in Melbourne, Australia, 1981-1990
#
# Units: Degrees Celcius
#
# #### Steps before loading
# - Rename the column name with temperature values to "Temperature"
# - In the last, there is one extra row in the data, remove it by opening the file and save it again.
# - There are some values in Temperature column which have a "?" before them, they will give error, remove "?" before them and save the file
# - If you don't want to do these steps, just load the data file given by Great Learning.

# %% [markdown]
# ### Import required libraries

# %% [markdown]
# #### Mount google drive

# %% [markdown]
# ### Load the  data file

# %% [markdown]
# ### Plot the data

# %% [markdown]
# ### Check for null values and treat them

# %% [markdown]
# #### Drop null values (if any)

# %% [markdown]
# ### Get the representation of the distribution of data in the form of histogram

# %% [markdown]
# ### Check the maximum and minimum values

# %% [markdown]
# ### Normalize the data

# %% [markdown]
# ### Check the maximum and minimum values of scaled data

# %% [markdown]
# ### Split data into Training and Testing set
# <u>Note</u> The train and test data has to be sequential. Keep the first 70% of data in training and the bottom 30% in test data

# %% [markdown]
# ## Create the sequential data
# Map the temperature at a particular time t to the temperature at time t+n, where n is any number you define.
#
# For example: to map temperatures of consecutive days, use t+1, i.e. loop_back = 1

# %% [markdown]
# #### Define your function to create dataset

# %% [markdown]
# ### Use function to get training and test set

# %% [markdown]
# ### Transform the prepared train and test input data into the expected structure using numpy.reshape()

# %% [markdown]
# ### Define sequntial model, add LSTM layer and compile the model

# %% [markdown]
# ### Train the model for 100 epochs with batch size = 1

# %% [markdown]
# ### Make Predictions and Evaluate your model

# %%
import math
from sklearn.metrics import mean_squared_error

trainPredict = model.predict(X_train, batch_size=batch_size)

model.reset_states()

testPredict = model.predict(X_test, batch_size=batch_size)

# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
y_train = scaler.inverse_transform([y_train])
testPredict = scaler.inverse_transform(testPredict)
y_test = scaler.inverse_transform([y_test])

# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(y_train[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(y_test[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-94-8d4b883d54af> in <module>()
#       2 from sklearn.metrics import mean_squared_error
#       3
# ----> 4 trainPredict = model.predict(X_train, batch_size=batch_size)
#       5
#       6 model.reset_states()
#
# NameError: name 'batch_size' is not defined
